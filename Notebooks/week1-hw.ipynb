# %% [markdown]
# # BL40A2030 Wireless Communication Networks
#
# ## Week 1 - Assignment
#
# ### Author: Jaime Arturo Álvarez Orgaz

# %% [markdown]
# ### Part I: Theory (40%)
#
# **1. Explain with your own words (1 or 2 paragraphs) the three-layer model presented in the lecture and in [[2]](https://www.ece.rutgers.edu/~marsic/books/CN/book-CN_marsic.pdf).**
#
# **2. Retransmissions via ARQ are important to the system reliability (lower packet error probability) but it has some drawbacks. However, it has some effects in the delay and traffic congestion. Describe with your own words one of the existing trade-offs.** (Hint: If restransmissions are allowed, the packet will stay in *walking* in the network more time).
#
# ### Part II: Jupyter NB experiments (60%)
#
# **3. Analyze a queue system similar to the tutorial considering $\lambda = 3$ and $\mu = 4$ for 2000 time periods.**
# - Plot a histogram of the queue sizes.
# - Compute the ratio of idle periods (0 elements in the queue) in relation to all time periods.
#
# **4. Analyze a queue system similar to the tutorial considering $\lambda = 4$ and $\mu = 3$ for 2000 time periods.**
# - Plot a histogram of the queue sizes.
# - Compute the ratio of idle periods (0 elements in the queue) in relation to all time periods.
#
# **5. Analyze a queue system similar to the tutorial considering $\lambda = 3$ and $\mu = 3$ for 2000 time periods.**
# - Plot a histogram of the queue sizes.
# - Compute the ratio of idle periods (0 elements in the queue) in relation to all time periods.

# %% [markdown]
# ### Part I:

# %% [markdown]
# **1:** The three-layer model is composed of the link layer, network layer and end-to-end layer. The link layer implements packet delivery between nodes. The network layer allows the connection between nodes. Lastly the end-to-end layer encapsulates all the communication feauters the application has.
#
# **2:** Some drawbacks of the retransmissions via ARQ would be the delay in transmissions while the receiver is waiting for the package to be retransmited. On the other hand it has flow and error control which benefits the channel communication.

# %% [markdown]
# ### Part II:

# %%
import numpy as np 
import matplotlib.pyplot as plt
from matplotlib import style
style.use('bmh')
#Not to show warning messages (to keep the notebook clean)
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# **3**

# %%
#time periods
size=2000
#Arrival
mean=3
arrival = np.random.poisson(mean, size)
#Service
mean=4
service = np.random.poisson(mean, size)
#
queue = np.zeros(size+1)

counter = 0

for i in range(size):
    if ((arrival[i] - service[i]) + queue[i]) > 0:
        queue[i+1] = max(0,(arrival[i] - service[i]) + queue[i])
    if queue[i] == 0:
        counter = counter + 1


plt.figure(figsize=(14,5))
plt.hist( queue )
plt.xlabel('$n$')
plt.ylabel('Size')
plt.title('Queue')
plt.grid(True) #grid
plt.show() 

print('Idle periods:', counter)
print('Idle periods ratio:', counter/size)
# Out:
# Idle periods: 1053
# Idle periods ratio: 0.5265

# %% [markdown]
# **4**

# %%
#time periods
size=2000
#Arrival
mean=4
arrival = np.random.poisson(mean, size)
#Service
mean=3
service = np.random.poisson(mean, size)
#
queue = np.zeros(size+1)

counter = 0

for i in range(size):
    if ((arrival[i] - service[i]) + queue[i]) > 0:
        queue[i+1] = max(0,(arrival[i] - service[i]) + queue[i])
    if queue[i] == 0:
        counter = counter + 1



plt.figure(figsize=(14,5))
plt.hist( queue )
plt.xlabel('$n$')
plt.ylabel('Size')
plt.title('Queue')
plt.grid(True) #grid
plt.show() 

print('Idle periods:', counter)
print('Idle periods ratio:', counter/size)
# Out:
# Idle periods: 2
# Idle periods ratio: 0.001

# %% [markdown]
# **5**

# %%
#time periods
size=2000
#Arrival
mean=3
arrival = np.random.poisson(mean, size)
#Service
mean=3
service = np.random.poisson(mean, size)
#
queue = np.zeros(size+1)

counter = 0

for i in range(size):
    if ((arrival[i] - service[i]) + queue[i]) > 0:
        queue[i+1] = max(0,(arrival[i] - service[i]) + queue[i])
    if queue[i] == 0:
        counter = counter + 1



plt.figure(figsize=(14,5))
plt.hist( queue )
plt.xlabel('$n$')
plt.ylabel('Size')
plt.title('Queue')
plt.grid(True) #grid
plt.show() 

print('Idle periods:', counter)
print('Idle periods ratio:', counter/size)
# Out:
# Idle periods: 44
# Idle periods ratio: 0.022
